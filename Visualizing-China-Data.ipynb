# %%
# %reset -f

# %%
import importlib
import codes.preprocess_covid_china
importlib.reload(codes.preprocess_covid_china)

from codes.preprocess_covid_china import (
    load_and_print_city_name_mapping,
    load_filtered_baidu_mobility_files,
    compute_average_mobility_matrix_with_threshold,
    extract_nodes_and_edges_from_matrix,
    inspect_mobility_data,
    load_and_filter_covid_timeseries,
    build_temporal_graph_data
)

# Step 1: Load city name mappings (CH <-> EN)
ch_to_en, en_to_ch = load_and_print_city_name_mapping(
    "./data/China/dataverse_files/info/Index_City_CH_EN.csv"
)

# Step 2: Load Baidu inflow mobility data (filtered to valid CH cities, mapped to EN)
valid_chinese_cities = set(ch_to_en.keys())
mobility_data = load_filtered_baidu_mobility_files(
    data_dir="./data/China/dataverse_files",
    kind="in",
    city_ch_to_en=ch_to_en,
    valid_chinese_cities=valid_chinese_cities
)

# Step 3: Inspect matrices
inspect_mobility_data(mobility_data)

# Step 4: Compute average matrix (only using aligned cities, thresholded by 10% presence)
avg_matrix, all_cities_in_mobility = compute_average_mobility_matrix_with_threshold(
    mobility_data, threshold=0.1
)

# Step 5: Load COVID-19 timeseries for cities in mobility matrix
covid_df = load_and_filter_covid_timeseries(
    file_path="./data/China/Covid-19 daily cases in China/covid-19 daily confirmed cases.xlsx",
    valid_english_cities=set(all_cities_in_mobility)
)

# Step 6: Filter average matrix and city list to only those 276 matched cities
matched_cities = list(covid_df.index)
matched_indices = [all_cities_in_mobility.index(city) for city in matched_cities if city in all_cities_in_mobility]

# Create filtered matrix and city list
import numpy as np
filtered_avg_matrix = avg_matrix[np.ix_(matched_indices, matched_indices)]
filtered_cities = [all_cities_in_mobility[i] for i in matched_indices]

# Step 7: Build graph using only matched cities
G_matched = extract_nodes_and_edges_from_matrix(filtered_avg_matrix, filtered_cities)

# Step 8: Filter COVID time series to match graph nodes (255 cities)
final_cities = list(G_matched.nodes)
print(len(G_matched.nodes))
covid_df_final = covid_df.loc[covid_df.index.intersection(final_cities)]

print(f"[✓] Filtered COVID DataFrame shape: {covid_df_final.shape}")
print(f"[✓] Preview of aligned COVID time series data:")
print(covid_df_final.head())

# Optional: preview
print(f"[✓] Final graph has {G_matched.number_of_nodes()} nodes and {G_matched.number_of_edges()} edges.")
# Out:
# [✓] Loading city name mappings from: ./data/China/dataverse_files/info/Index_City_CH_EN.csv
# [✓] Total mappings: 342
# [✓] No missing Chinese names
# [✓] No missing English names
# [✓] No duplicated Chinese names
# [✓] Duplicated English names: 5
# [✓] Sample mappings (CH -> EN):
#     北京市 -> Beijing
#     天津市 -> Tianjin
#     石家庄市 -> Shijiazhuang
#     唐山市 -> Tangshan
#     秦皇岛市 -> Qinhuangdao
#     邯郸市 -> Handan
#     邢台市 -> Xingtai
#     保定市 -> Baoding
#     张家口市 -> Zhangjiakou
#     承德市 -> Chengde
# [✓] Scanning for Baidu in files in: ./data/China/dataverse_files
# [✓] Loaded 540 mobility matrices for kind='in'
# [✓] Sample matrix on 2020-01-01:
#               Beijing  Tianjin  Shanghai  Chongqing  Shijiazhuang  Tangshan  \
# Beijing           NaN    17.46      2.20       1.64          7.89     11.84
# Tianjin          7.79      NaN      0.55       0.48          2.83     28.04
# Shanghai         1.62     0.83       NaN       1.93          0.52      0.35
# Chongqing        0.55     0.35      0.70        NaN          0.25      0.10
# Shijiazhuang     2.39     2.23      0.21       0.35           NaN      4.11
#
#               Qinhuangdao  Handan  Xingtai  Baoding  ...  Changjihuizu  \
# Beijing             10.14   12.07     7.86    32.79  ...          0.29
# Tianjin              6.77    6.87     2.66     4.88  ...          0.08
# Shanghai             0.44    0.48     0.33     0.30  ...          0.13
# Chongqing            0.13    0.21     0.11     0.12  ...          0.11
# Shijiazhuang         3.40   12.83    30.16    17.20  ...          0.03
#
#               Boertalamenggu  Bayinguolengmenggu  Akesudiqu  Kezilesukeerkezi  \
# Beijing                 0.03                0.77       0.36              0.23
# Tianjin                 0.03                0.21       0.04               NaN
# Shanghai                0.17                0.13       0.08               NaN
# Chongqing               0.13                0.36       0.44              0.17
# Shijiazhuang            0.03                0.12       0.06               NaN
#
#               Kashendiqu  Hetiandiqu  Yilihasake  Tachengdi  Aletaidi
# Beijing             0.55        0.89        0.60       0.17      0.31
# Tianjin             0.07        0.14        0.18       0.08      0.07
# Shanghai            0.21        0.14        0.21       0.05      0.15
# Chongqing           0.25        0.14        0.15       0.12      0.23
# Shijiazhuang         NaN        0.04        0.09        NaN      0.03
#
# [5 rows x 303 columns]
# [✓] Inspected 540 matrices.
# [✓] Unique matrix shapes: [(303, 303), (0, 0)]
#     2020-01-01: (303, 303)
#     2020-01-02: (303, 303)
#     2020-01-03: (303, 303)
#     2020-01-04: (303, 303)
#     2020-01-05: (303, 303)
#
# [✓] Matrix shape counts:
#     (303, 303): 68 matrices
#     (0, 0): 472 matrices
#
# [!] Example of empty matrix: 2020-03-09
# [✓] Computing average mobility matrix with threshold=10%
# [✓] Averaged over 68 matrices
# [✓] Number of common cities: 303
# [✓] Loading COVID-19 case data from: ./data/China/Covid-19 daily cases in China/covid-19 daily confirmed cases.xlsx
# [✓] Matched cities: 276
# [!] Unmatched cities: 86
# [!] Example unmatched: ['Bijie', 'Haiximengguzuzangzuzizhizhou', 'Zhaotong', 'Baise', 'Naqushi', 'Linzhishi', 'Chengmai County', 'Qiannanbuyizumiaozuzizhizhou', 'Haidongshi', 'Nujianglisuzuzizhizhou']
# [✓] Final shape: (276, 694)
# [✓] Date range: 2020-01-20 00:00:00 to 2021-12-12 00:00:00
# [✓] Example matched cities: ['Beijing', 'Tianjin', 'Shijiazhuang', 'Tangshan', 'Qinhuangdao']
# [•] Scanning matrix to gather all edges...
# [✓] Total raw edges before filtering: 61733
# [!] Cities with 0 outgoing edges in raw matrix: 0 → []
# [•] Applying backbone filtering (pij + top-k)...
# [✓] Edges after filtering: 3490
# [✓] pij < alpha: 3445, top-5 edges kept: 1317
# ✓ Actually added 3008 unique edges.
# [!] Isolated cities (no mobility edges): 0 → []
# [✓] Final graph: 255 nodes, 3008 edges
# 255
# [✓] Filtered COVID DataFrame shape: (276, 694)
# [✓] Preview of aligned COVID time series data:
#               2020-01-20  2020-01-21  2020-01-22  2020-01-23  2020-01-24  \
# City_name
# Beijing        -0.354133    2.517954    1.287059    2.517954    0.671612
# Tianjin        -0.497401   -0.497401    2.073894    2.073894    0.788247
# Shijiazhuang   -0.164899   -0.164899   -0.164899   -0.046062    0.191611
# Tangshan       -0.146727   -0.146727   -0.146727   -0.146727   -0.146727
# Qinhuangdao    -0.095329   -0.095329   -0.095329   -0.095329   -0.095329
#
#               2020-01-25  2020-01-26  2020-01-27  2020-01-28  2020-01-29  ...  \
# City_name                                                                 ...
# Beijing         5.184893    2.107656    1.902507    3.748849    0.261314  ...
# Tianjin         2.073894    5.288013    0.145423    1.431070    2.073894  ...
# Shijiazhuang   -0.046062    0.072775    0.072775   -0.046062   -0.046062  ...
# Tangshan       -0.146727   -0.146727    1.608936    3.364599   -0.146727  ...
# Qinhuangdao    -0.095329   -0.095329   -0.095329   -0.095329   -0.095329  ...
#
#               2021-12-03  2021-12-04  2021-12-05  2021-12-06  2021-12-07  \
# City_name
# Beijing        -0.354133   -0.148984   -0.354133   -0.354133   -0.148984
# Tianjin        -0.497401   -0.497401    0.145423    0.145423   -0.497401
# Shijiazhuang    0.310448   -0.164899   -0.046062   -0.164899   -0.164899
# Tangshan       -0.146727   -0.146727   -0.146727   -0.146727   -0.146727
# Qinhuangdao    -0.095329   -0.095329   -0.095329   -0.095329   -0.095329
#
#               2021-12-08  2021-12-09  2021-12-10  2021-12-11  2021-12-12
# City_name
# Beijing        -0.354133   -0.354133    0.056165   -0.354133   -0.354133
# Tianjin        -0.497401   -0.497401   -0.497401   -0.497401   -0.497401
# Shijiazhuang   -0.164899   -0.164899   -0.164899   -0.164899   -0.164899
# Tangshan       -0.146727   -0.146727   -0.146727   -0.146727   -0.146727
# Qinhuangdao    -0.095329   -0.095329   -0.095329   -0.095329   -0.095329
#
# [5 rows x 694 columns]
# [✓] Final graph has 255 nodes and 3008 edges.

# %%
import torch

if torch.backends.mps.is_available():
    device = torch.device("cpu")
    print('Using cpu')
elif torch.cuda.is_available():
    device = torch.device("cuda")
else:
    device = torch.device("cpu")
# Out:
# Using cpu
